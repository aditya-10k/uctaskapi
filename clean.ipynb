# %%
import pandas as pd

df = pd.read_csv("gamedata1.csv")
df
# Out:
#                                       Title  Year Rated     Released  Runtime  \
# 0                    Red Dead Redemption II  2018     M  26 Oct 2018      NaN
# 1                            The Last of Us  2013     M  14 Jun 2013      NaN
# 2                  The Witcher 3: Wild Hunt  2015     M  19 May 2015      NaN
# 3                                God of War  2018     M  20 Apr 2018      NaN
# 4      The Legend of Zelda: Ocarina of Time  1998     E  23 Nov 1998      NaN
# 5                             Mass Effect 2  2010     M  26 Jan 2010      NaN
# 6                        Grand Theft Auto V  2013     M  17 Sep 2013      NaN
# 7                          Metal Gear Solid  1998     M  21 Oct 1998      NaN
# 8                Uncharted 4: A Thief's End  2016     T  10 May 2016      NaN
# 9    Star Wars: Knights of the Old Republic  2003     T  18 Jul 2003      NaN
# 10                        Final Fantasy VII  1997     T  07 Sep 1997      NaN
# ...

# %%
df['Runtime'].drop()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17208\3991852643.py in ?()
# ----> 1 df['Runtime'].drop()
#
# c:\Users\kathe\anaconda3\Lib\site-packages\pandas\core\series.py in ?(self, labels, axis, index, columns, level, inplace, errors)
#    5352         falcon  speed     320.0
#    5353                 length      0.3
#    5354         dtype: float64
#    5355         """
# -> 5356         return super().drop(
#    5357             labels=labels,
#    5358             axis=axis,
#    5359             index=index,
#
# c:\Users\kathe\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, labels, axis, index, columns, level, inplace, errors)
#    4776             axes = {"index": index}
#    4777             if self.ndim == 2:
#    4778                 axes["columns"] = columns
#    4779         else:
# ...

# %%
df1 = df.drop(columns=['Runtime'])
df1
# Out:
#                                       Title  Year Rated     Released  \
# 0                    Red Dead Redemption II  2018     M  26 Oct 2018
# 1                            The Last of Us  2013     M  14 Jun 2013
# 2                  The Witcher 3: Wild Hunt  2015     M  19 May 2015
# 3                                God of War  2018     M  20 Apr 2018
# 4      The Legend of Zelda: Ocarina of Time  1998     E  23 Nov 1998
# 5                             Mass Effect 2  2010     M  26 Jan 2010
# 6                        Grand Theft Auto V  2013     M  17 Sep 2013
# 7                          Metal Gear Solid  1998     M  21 Oct 1998
# 8                Uncharted 4: A Thief's End  2016     T  10 May 2016
# 9    Star Wars: Knights of the Old Republic  2003     T  18 Jul 2003
# 10                        Final Fantasy VII  1997     T  07 Sep 1997
# 11                           Chrono Trigger  1995   NaN  22 Aug 1995
# 12              The Elder Scrolls V: Skyrim  2011     M  11 Nov 2011
# ...

# %%
df1.to_csv("cleanedgamedata.csv")
